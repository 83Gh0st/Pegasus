# %%
import os
from glob import glob # extract path of each file
import pandas as pd # data preprocessing
from xml.etree import ElementTree as et # parse information from XML
from functools import reduce

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# step-1: get path of each xml file
xmlfiles = glob('/home/cpow/Desktop/pegasus/datasets/valid/*.xml')
# replace \\ with /
replace_text = lambda x: x.replace('\\','/')
xmlfiles = list(map(replace_text,xmlfiles))

# %%
xmlfiles
# Out:
# ['/home/cpow/Desktop/pegasus/datasets/valid/image_317_jpg.rf.7e994ca9e9a99feba22861c3eaff634e.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/image_194_jpg.rf.f4b70c520b6deab116ebe4c875fdcb08.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/image_213_jpg.rf.9f731d3d872c5ed77a8ababbef415f06.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/image_169_jpg.rf.969c4f8e28061136d7ce9d4887da1259.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/image_222_jpg.rf.66dc43b804487d560c3965d3077c1401.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/ppe_0926_jpg.rf.a1616137fe6bde3f797bf82a8b7a821d.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/Twalv0509_jpg.rf.936f594299864a5a7162d8803e9d0263.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/TsirinTu0020_jpg.rf.6616844bcb76ec053233b96e3f5e981e.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/image_155_jpg.rf.92495fba618249dbe74d79e77d05c1bc.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/image_168_jpg.rf.8e24a61b3f4300bf9a7800ac60f97e33.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/image_214_jpg.rf.cd1dd028c9e8abdaed0ce5f50a58e6ee.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/Twalv0799_jpg.rf.40154c4992783afaf7c34d57617b1bb0.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/Nein6244_jpg.rf.6c40caba756fdd0f599a0ed3e8bd0f1d.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/TsirinTu0012_jpg.rf.466bed8bdcdc9963ef91ae647b8c5355.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/image_221_jpg.rf.6d1a33a383d47296984e135975099e38.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/image_173_jpg.rf.292611a36de0c991ebc4708436444bf6.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/image_215_jpg.rf.ed55e1d33cc888561b21bc9cd3bd7474.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/Tan0125_jpg.rf.963e595e04db466bb9451730eba26ad3.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/image_225_jpg.rf.f37f44502a9b306c1f73df73a600f4ad.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/image_186_jpg.rf.03d010490b4e58e0bbb96157a970bdac.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/Photin1249_jpg.rf.528e84963f4652a8baf2208dea4ace3b.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/image_158_jpg.rf.704db11fb082d99b6f3652d6cb903afa.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/TsirinTu0046_jpg.rf.2a730f14d6fc59ec65d3f11525756107.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/image_193_jpg.rf.64d592dda6039aac4dcbc8fce7d6ed48.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/Twalv1204_jpg.rf.5839e4e3437c3c90699b6c95e7fb39fd.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/image_161_jpg.rf.5f7ce64b1cdaae6b027bd3c8191a0d4c.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/ppe_0144_jpg.rf.01d8f96556bd94baefb61cdb3f5bb1fc.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/image_202_jpg.rf.2b08ef7859272178e29b1fd69f2359c2.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/AightOne0410_jpg.rf.7d795823ed5b35f128d1d59b3ff0f701.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/Twalv0440_jpg.rf.fa484e71fba5924481312ecf80949e54.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/image_232_jpg.rf.c4ccb746ce8b3a2ed894cbf0c6120bbc.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/images-2022-07-04T013045_jpg.rf.2a1a931470965ddd05f3b48613c3d671.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/Twalv0282_jpg.rf.497728848600a507b802907c5810d6b3.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/image_221_jpg.rf.9e0796a058f9932129459525dfc2e005.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/ppe_0364_jpg.rf.b265e6d6d2b1fbda94ddc1b3cb70ee51.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/image_166_jpg.rf.7f80475bcb72c19a371e0c2e2e9d48d0.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/KakaoTalk_20221018_001605157_29_jpg.rf.de68c764977478c3ce11ce104f9d0a19.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/image_190_jpg.rf.4776ee1a28323631a4796ebe3788b84d.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/image_156_jpg.rf.097db0fbfb461bae4cfbcb2dd2890082.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/image_163_jpg.rf.28ac43ba27208ec107288c32cc5e1d95.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/Twalv1131_jpg.rf.cc0d809083d82d4d31a46350bb965a2d.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/Twalv0801_jpg.rf.62ef0e2e695d0c43470346729eabba7b.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/Aitin3617_jpg.rf.8ed98833b39904007383b6619c778ecc.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/Photin0243_jpg.rf.8d8233359651617f72fb7483c352fff6.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/Photin1166_jpg.rf.5c08e46a94e60e1d0ad4eac5f35d9db2.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/thumb0923_jpg.rf.4b30c16db0e1247c42322d03cb075944.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/ppe_0307_jpg.rf.d4c7ed554ae4447601cd959a5a0658f7.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/ppe_0941_jpg.rf.1c684d155ac473867360523db102418d.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/Aitin1720_jpg.rf.90832f3078fccf928e2aba8084cba933.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/20220621_132901_jpg.rf.c91202e41776b215b440bbe397a7dc7e.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/Tan0617617_jpg.rf.7b006e492ad02d2f3a07a9ea9daaf304.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/Twalv0536_jpg.rf.0678fabfd74db206e2b25bbc8f4d0711.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/ppe_0895_jpg.rf.39ac899303d4cc8566884b8ba957ae28.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/image_179_jpg.rf.e4b258886b6067c32086b4e9bbfa6c68.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/Twalv1202_jpg.rf.ce9c629b16e1f78d7eaea7850d975afa.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/thumb0452_jpg.rf.80fbb13419f495c9609936b5b35edb09.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/Twalv1139_jpg.rf.c743edc180335ffab3bb33e89ac651d5.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/Nein1018_jpg.rf.07318eb634ab69c41f32493668ff42a4.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/image_261_jpg.rf.a7d02b98021ea75ba231349d600edbee.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/KakaoTalk_20221018_001219713_16_jpg.rf.9c2c836f6fd9ac23a6bae2977ea78800.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/Aitin1845_jpg.rf.39d022fe73dfa38d621521bc8783cc09.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/Nein5000_jpg.rf.3b72c786a78bccf116b1d892a891700b.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/thumb0454_jpg.rf.780fea14eea04abfe53d826841aa6eac.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/KakaoTalk_20221018_001312059_02_jpg.rf.709c44354465ccb011777031642e1b82.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/20220621_132924_jpg.rf.973acdebca6fdad41c3afd47649a7890.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/ppe_1200_jpg.rf.54b8f9cbd02466a305bbed17e8471df8.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/image_156_jpg.rf.e469cd43c5639f6e2ce3a11e15ed314f.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/image_179_jpg.rf.794286cebf7c7446f4faaed8d1dea8b9.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/image_258_jpg.rf.a8ec6c4d0fc95354e87840d418eb78a1.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/image_211_jpg.rf.a29709f204a790b1255adf3f7aef3bdb.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/image_171_jpg.rf.103b1eede1c9fe53f50cf81ff7716140.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/Photin0973_jpg.rf.e1a1de3626bf52b0c5ce3d9be0ae21cf.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/ppe_0974_jpg.rf.26a2a1469b2f68a64642b74405142ed6.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/Tan0296_jpg.rf.9544f281060ab09a65bc35f7afa8a5d5.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/9417812-serious-male-construction-worker-in-safety-vest-and-hard-hat_jpg.rf.74b2b3ad8356e42222ba0bf27efca02c.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/ppe_0153_jpg.rf.51e992624b9f5130719ac54e96ed8bed.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/Tan0639639_jpg.rf.24eb87e2d3ed2eb4b5177ea9f59ac4a4.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/image_181_jpg.rf.e0e9cb8269dfc223c71e5b05dd237ad8.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/image_253_jpg.rf.330c50648c90ea1df698a2e459bcf70e.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/thumb2490_jpg.rf.b2ed621ef19be06863b182293f1e34b2.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/image_160_jpg.rf.3efc513909674ccefbd4296b906b3de5.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/Twalv1103_jpg.rf.76a92bee35bb5ccc0ac1b213054fcfee.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/image_257_jpg.rf.5ce183c19423145abb992d525a563db3.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/image_153_jpg.rf.ea264f013a7f8543901db2ebb90be768.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/KakaoTalk_20221018_001425789_23_jpg.rf.22f5040cde1a64dd7d41ea333622c9d1.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/image_174_jpg.rf.e7a81e07572b603626aab548b00a5173.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/image_163_jpg.rf.8ef5d34ff2e9e0188130212eeb77bf08.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/image_166_jpg.rf.140246ad465a06b5c890609072823f47.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/image_183_jpg.rf.675600a6b467d55f30a5eeccedf59e9c.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/image_236_jpg.rf.fc7af010b61ebea7e850b79da0168126.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/Photin0730_jpg.rf.0a330b5b732f6092fb540df25ca54a47.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/thumb2435_jpg.rf.6ed98b55f463c858a51ebe3cf75cc73a.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/Twalv0314_jpg.rf.2a738aebebc33804a017a63b701eb797.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/Aitin1788_jpg.rf.a280f21d302b03b3dbd7109cd79b2fb4.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/KakaoTalk_20221018_001605157_12_jpg.rf.1d0361e820dc87630f02fdf741f05c08.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/image_190_jpg.rf.1f19bf4d64d208f18a38f47e824b74d4.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/image_150_jpg.rf.789268a69dd89c8487e1d5e6ed2c0976.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/Photin0098_jpg.rf.04e67bab61f058e91c5dc71dbc0a2293.xml',
#  '/home/cpow/Desktop/pegasus/datasets/valid/00000383_jpg.rf.19f86e46355164db622b03bfaf4acaec.xml']

# %%
# step-2: read xml files
# from each xml file we need to extract
# filename, size(width, height), object(name, xmin, xmax, ymin, ymax)
def extract_text(filename):
    tree = et.parse(filename)
    root = tree.getroot()

    # extract filename
    image_name = root.find('filename').text
    # width and height of the image
    width = root.find('size').find('width').text
    height = root.find('size').find('height').text
    objs = root.findall('object')
    parser = []
    for obj in objs:
        name = obj.find('name').text
        bndbox = obj.find('bndbox')
        xmin = bndbox.find('xmin').text
        xmax = bndbox.find('xmax').text
        ymin = bndbox.find('ymin').text
        ymax = bndbox.find('ymax').text
        parser.append([image_name, width, height, name,xmin,xmax,ymin,ymax])
        
    return parser

# %%
parser_all = list(map(extract_text,xmlfiles))

# %%
data = reduce(lambda x, y : x+y,parser_all)

# %%
df = pd.DataFrame(data,columns = ['filename','width','height','name','xmin','xmax','ymin','ymax'])

# %%
df.head()
# Out:
#                                             filename width height  \
# 0  image_317_jpg.rf.7e994ca9e9a99feba22861c3eaff6...   640    640
# 1  image_317_jpg.rf.7e994ca9e9a99feba22861c3eaff6...   640    640
# 2  image_317_jpg.rf.7e994ca9e9a99feba22861c3eaff6...   640    640
# 3  image_317_jpg.rf.7e994ca9e9a99feba22861c3eaff6...   640    640
# 4  image_317_jpg.rf.7e994ca9e9a99feba22861c3eaff6...   640    640
#
#           name xmin xmax ymin ymax
# 0  Safety-Boot  390  423  482  549
# 1  Safety-Boot  453  513  543  590
# 2       Gloves  484  518  384  430
# 3  Safety-Vest  426  505  213  369
# 4       Person  368  549  126  611

# %%
df.shape
# Out:
# (564, 8)

# %%
df['name'].value_counts()
# Out:
# name
# Safety-Boot        118
# Gloves              91
# vest                78
# Person              69
# Safety-Vest         67
# Helmet              53
# Glass               35
# No-Helmet           22
# helmet              15
# Goggles              4
# protective_suit      3
# no helmet            2
# Vest                 2
# No-Vest              1
# no_helmet            1
# no_vest              1
# no vest              1
# worker               1
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 564 entries, 0 to 563
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  564 non-null    object
#  1   width     564 non-null    object
#  2   height    564 non-null    object
#  3   name      564 non-null    object
#  4   xmin      564 non-null    object
#  5   xmax      564 non-null    object
#  6   ymin      564 non-null    object
#  7   ymax      564 non-null    object
# dtypes: object(8)
# memory usage: 35.4+ KB

# %%
# type conversion
cols = ['width','height','xmin','xmax','ymin','ymax']
df[cols] = df[cols].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 564 entries, 0 to 563
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  564 non-null    object
#  1   width     564 non-null    int64
#  2   height    564 non-null    int64
#  3   name      564 non-null    object
#  4   xmin      564 non-null    int64
#  5   xmax      564 non-null    int64
#  6   ymin      564 non-null    int64
#  7   ymax      564 non-null    int64
# dtypes: int64(6), object(2)
# memory usage: 35.4+ KB

# %%
# center x, center y
df['center_x'] = ((df['xmax']+df['xmin'])/2)/df['width']
df['center_y'] = ((df['ymax']+df['ymin'])/2)/df['height']
# w 
df['w'] = (df['xmax']-df['xmin'])/df['width']
# h 
df['h'] = (df['ymax']-df['ymin'])/df['height']

# %%
df.head()
# Out:
#                                             filename  width  height  \
# 0  image_317_jpg.rf.7e994ca9e9a99feba22861c3eaff6...    640     640
# 1  image_317_jpg.rf.7e994ca9e9a99feba22861c3eaff6...    640     640
# 2  image_317_jpg.rf.7e994ca9e9a99feba22861c3eaff6...    640     640
# 3  image_317_jpg.rf.7e994ca9e9a99feba22861c3eaff6...    640     640
# 4  image_317_jpg.rf.7e994ca9e9a99feba22861c3eaff6...    640     640
#
#           name  xmin  xmax  ymin  ymax  center_x  center_y         w         h
# 0  Safety-Boot   390   423   482   549  0.635156  0.805469  0.051562  0.104688
# 1  Safety-Boot   453   513   543   590  0.754687  0.885156  0.093750  0.073438
# 2       Gloves   484   518   384   430  0.782813  0.635938  0.053125  0.071875
# 3  Safety-Vest   426   505   213   369  0.727344  0.454688  0.123438  0.243750
# 4       Person   368   549   126   611  0.716406  0.575781  0.282813  0.757812

# %%
images = df['filename'].unique()

# %%
len(images)
# Out:
# 99

# %%
# 80% train and 20% test
img_df = pd.DataFrame(images,columns=['filename'])
img_train = tuple(img_df.sample(frac=0.8)['filename']) # shuffle and pick 80% of images

# %%
img_test = tuple(img_df.query(f'filename not in {img_train}')['filename']) # take rest 20% images

# %%
len(img_train), len(img_test)
# Out:
# (79, 20)

# %%
train_df = df.query(f'filename in {img_train}')
test_df = df.query(f'filename in {img_test}')

# %%
train_df.head()
# Out:
#                                             filename  width  height  \
# 0  image_317_jpg.rf.7e994ca9e9a99feba22861c3eaff6...    640     640
# 1  image_317_jpg.rf.7e994ca9e9a99feba22861c3eaff6...    640     640
# 2  image_317_jpg.rf.7e994ca9e9a99feba22861c3eaff6...    640     640
# 3  image_317_jpg.rf.7e994ca9e9a99feba22861c3eaff6...    640     640
# 4  image_317_jpg.rf.7e994ca9e9a99feba22861c3eaff6...    640     640
#
#           name  xmin  xmax  ymin  ymax  center_x  center_y         w         h
# 0  Safety-Boot   390   423   482   549  0.635156  0.805469  0.051562  0.104688
# 1  Safety-Boot   453   513   543   590  0.754687  0.885156  0.093750  0.073438
# 2       Gloves   484   518   384   430  0.782813  0.635938  0.053125  0.071875
# 3  Safety-Vest   426   505   213   369  0.727344  0.454688  0.123438  0.243750
# 4       Person   368   549   126   611  0.716406  0.575781  0.282813  0.757812

# %%
test_df.head()
# Out:
#                                              filename  width  height  \
# 13  image_213_jpg.rf.9f731d3d872c5ed77a8ababbef415...    640     640
# 14  image_213_jpg.rf.9f731d3d872c5ed77a8ababbef415...    640     640
# 15  image_213_jpg.rf.9f731d3d872c5ed77a8ababbef415...    640     640
# 16  image_213_jpg.rf.9f731d3d872c5ed77a8ababbef415...    640     640
# 17  image_213_jpg.rf.9f731d3d872c5ed77a8ababbef415...    640     640
#
#            name  xmin  xmax  ymin  ymax  center_x  center_y         w  \
# 13  Safety-Boot   323   378   545   641  0.547656  0.926562  0.085938
# 14  Safety-Boot   376   450   577   633  0.645312  0.945312  0.115625
# 15       Person   311   498   100   641  0.632031  0.578906  0.292187
# 16    No-Helmet   391   471    99   216  0.673438  0.246094  0.125000
# 17        Glass   405   471   135   173  0.684375  0.240625  0.103125
#
#            h
# 13  0.150000
# 14  0.087500
# 15  0.845313
# 16  0.182812
# 17  0.059375

# %%
def label_encoding(x):
    labels = {
        'hat': 0, 
        'vest': 1, 
        'no hat': 2, 
        'no vest': 3,
        'Glass': 4,
        'Gloves': 5,
        'Goggles': 6,
        'Helmet': 7,
        'No-Helmet': 8,
        'No-Vest': 9,
        'Person': 10,
        'Safety-Boot': 11,
        'Safety-Vest': 12,
        'Vest': 13,
        'helmet': 14,
        'no helmet': 15,
        'no vest': 16,
        'no_helmet': 17,
        'no_vest': 18,
        'protective_suit': 19,
        'worker': 20
    }
    return labels[x]

# %%
train_df['id'] = train_df['name'].apply(label_encoding)
test_df['id'] = test_df['name'].apply(label_encoding)

# %%
train_df.head(10)
# Out:
#                                             filename  width  height  \
# 0  image_317_jpg.rf.7e994ca9e9a99feba22861c3eaff6...    640     640
# 1  image_317_jpg.rf.7e994ca9e9a99feba22861c3eaff6...    640     640
# 2  image_317_jpg.rf.7e994ca9e9a99feba22861c3eaff6...    640     640
# 3  image_317_jpg.rf.7e994ca9e9a99feba22861c3eaff6...    640     640
# 4  image_317_jpg.rf.7e994ca9e9a99feba22861c3eaff6...    640     640
# 5  image_317_jpg.rf.7e994ca9e9a99feba22861c3eaff6...    640     640
# 6  image_194_jpg.rf.f4b70c520b6deab116ebe4c875fdc...    640     640
# 7  image_194_jpg.rf.f4b70c520b6deab116ebe4c875fdc...    640     640
# 8  image_194_jpg.rf.f4b70c520b6deab116ebe4c875fdc...    640     640
# 9  image_194_jpg.rf.f4b70c520b6deab116ebe4c875fdc...    640     640
#
#           name  xmin  xmax  ymin  ymax  center_x  center_y         w  \
# 0  Safety-Boot   390   423   482   549  0.635156  0.805469  0.051562
# 1  Safety-Boot   453   513   543   590  0.754687  0.885156  0.093750
# 2       Gloves   484   518   384   430  0.782813  0.635938  0.053125
# 3  Safety-Vest   426   505   213   369  0.727344  0.454688  0.123438
# 4       Person   368   549   126   611  0.716406  0.575781  0.282813
# 5    No-Helmet   421   504   141   216  0.722656  0.278906  0.129688
# 6  Safety-Vest   185   286   177   361  0.367969  0.420312  0.157812
# 7       Helmet   190   247    89   141  0.341406  0.179688  0.089063
# 8       Gloves   184   232   187   231  0.325000  0.326562  0.075000
# 9       Gloves   248   293   167   211  0.422656  0.295312  0.070312
#
#           h  id
# 0  0.104688  11
# 1  0.073438  11
# 2  0.071875   5
# 3  0.243750  12
# 4  0.757812  10
# 5  0.117188   8
# 6  0.287500  12
# 7  0.081250   7
# 8  0.068750   5
# 9  0.068750   5

# %%
import os
from shutil import move

# %%
train_folder = '/home/cpow/Desktop/pegasus/datasets/train'
test_folder = '/home/cpow/Desktop/pegasus/datasets/test'


os.mkdir(train_folder)
os.mkdir(test_folder)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[131], line 5
#       1 train_folder = '/home/cpow/Desktop/pegasus/datasets/train'
#       2 test_folder = '/home/cpow/Desktop/pegasus/datasets/test'
# ----> 5 os.mkdir(train_folder)
#       6 os.mkdir(test_folder)
#
# FileExistsError: [Errno 17] File exists: '/home/cpow/Desktop/pegasus/datasets/train'

# %%
cols = ['filename','id','center_x','center_y', 'w', 'h']
groupby_obj_train = train_df[cols].groupby('filename')
groupby_obj_test = test_df[cols].groupby('filename')

# %%
#groupby_obj_train.get_group('000009.jpg').set_index('filename').to_csv('sample.txt',index=False,header=False)
# save each image in train/test folder and repective labels in .txt
def save_data(filename, folder_path, group_obj):
    # move image
    src = os.path.join('/home/cpow/Desktop/pegasus/datasets/valid',filename)
    dst = os.path.join(folder_path,filename)
    move(src,dst) # move image to the destination folder
    
    # save the labels
    text_filename = os.path.join(folder_path,
                                 os.path.splitext(filename)[0]+'.txt')
    group_obj.get_group(filename).set_index('filename').to_csv(text_filename,sep=' ',index=False,header=False)

# %%
filename_series = pd.Series(groupby_obj_train.groups.keys())

# %%
filename_series.apply(save_data,args=(train_folder,groupby_obj_train))
# Out:
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
#       ...
# 74    None
# 75    None
# 76    None
# 77    None
# 78    None
# Length: 79, dtype: object

# %%
filename_series_test = pd.Series(groupby_obj_test.groups.keys())
filename_series_test.apply(save_data,args=(test_folder,groupby_obj_test))
# Out:
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11    None
# 12    None
# 13    None
# 14    None
# 15    None
# 16    None
# 17    None
# 18    None
# 19    None
# dtype: object
